# %%
import sys
import os
import uproot
import matplotlib as mpl
import matplotlib.pylab as pylab
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import awkward as ak

# %% [markdown]
# ## Set Up and Load the DataFrame

# %%
# List of variables to include in the DataFrame

# variables = ['selected', 'evt', 'sub', 'run', 'nslice', 'shr_energy_tot_cali','_opfilter_pe_beam',
#              '_opfilter_pe_veto','slice_orig_pass_id','n_tracks_contained', 'truthFiducial', 'npi0', 'elec_e',
#             'CosmicIPAll3D', 'hits_ratio', 'shrmoliereavg', 'subcluster', 'trkfit', 'tksh_distance', #'shr_tkfit_nhits_tot',
#             'shr_tkfit_dedx_max', 'n_showers_contained', 'shr_tkfit_nhits_Y', 'shr_tkfit_nhits_U', 'shr_tkfit_nhits_V']

variables = ['evt', 'run', 'slice_orig_pass_id', 'truthFiducial', 'npi0', 'elec_e', 
             'shr_tkfit_nhits_Y', 'shr_tkfit_nhits_U', 'shr_tkfit_nhits_V']

added_vars = ['shr_tkfit_nhits_tot', 'trksemlbl', 'trkpid']

new_loose_cut_variables = [
    'nslice',
    'selected',
    'shr_energy_tot_cali',
    '_opfilter_pe_beam',
    '_opfilter_pe_veto',
    'n_tracks_contained',
    'CosmicIPAll3D',
    'trksemlbl',
    'hits_ratio',
    'shrmoliereavg',
    'subcluster',
    'trkfit',
    'tksh_distance',
    'shr_tkfit_nhits_tot',
    'shr_tkfit_dedx_max',
    'n_showers_contained'
]

variables.extend(new_loose_cut_variables)
variables = list(set([var for var in variables if var not in added_vars]))
variables
# Out:
# ['_opfilter_pe_veto',
#  'npi0',
#  'truthFiducial',
#  'shr_tkfit_nhits_V',
#  'elec_e',
#  'shrmoliereavg',
#  'tksh_distance',
#  'slice_orig_pass_id',
#  'CosmicIPAll3D',
#  'shr_energy_tot_cali',
#  'n_tracks_contained',
#  'shr_tkfit_nhits_U',
#  'shr_tkfit_nhits_Y',
#  'selected',
#  'subcluster',
#  'shr_tkfit_dedx_max',
#  '_opfilter_pe_beam',
#  'run',
#  'trkfit',
#  'hits_ratio',
#  'nslice',
#  'evt',
#  'n_showers_contained']

# %%
# Load one file for easier viewing
t = uproot.open('DetVar/v01/prodgenie_bnb_intrinsic_nue_overlay_DetVar_CV_reco2_v08_00_00_38_run1_reco2_reco2.root')['nuselection']['NeutrinoSelectionFilter']
df = t.arrays(variables, library="pd")
df.sort_values(by=['run','evt']).head(25)
# Out:
#        tksh_distance  shr_tkfit_nhits_V  n_showers_contained   run  \
# 26905  -3.402823e+38                  0                    0  4952
# 26906   3.022484e+02                  0                    1  4952
# 26907  -3.402823e+38                  0                    0  4952
# 26908   9.708457e+02                  5                    1  4952
# 14233   1.759818e+00                 10                    0  4953
# 14234   3.859823e+00                  1                    1  4953
# 14235  -3.402823e+38                  0                    0  4953
# 14236   3.811536e+00                  8                    3  4953
# 14237  -3.402823e+38                  0                    0  4953
# 14238   9.973590e-01                  9                    1  4953
# 14239   1.180811e+00                  3                    1  4953
# 14240  -3.402823e+38                  0                    0  4953
# 14241   1.044884e+02                  0                    1  4953
# 14242   9.802182e-01                  6                    1  4953
# 14243  -3.402823e+38                  0                    0  4953
# 14244  -3.402823e+38                  0                    0  4953
# 14245   4.250979e+01                  2                    1  4953
# 14246   2.627992e+00                 11                    1  4953
# 14247  -3.402823e+38                  0                    0  4953
# 14248   1.365721e+00                  4                    1  4953
# 14249   3.659254e+02                  9                    1  4953
# 14250   7.500024e+02                  0                    0  4953
# 14251   2.229995e-01                  5                    1  4953
# 14252   1.421241e+00                  0                    2  4953
# 14253   4.118145e+00                  7                    1  4953
#
#        shr_energy_tot_cali  nslice  slice_orig_pass_id   evt  \
# 26905             0.000000       0                   0  3371
# 26906             0.114463       1                   1  3380
# 26907             0.000000       0                   1  3387
# 26908             0.922366       1                   0  3390
# 14233             0.033863       1                   0  2527
# 14234             0.347280       1                   1  2577
# 14235             0.000000       0                   0  2615
# 14236             0.394034       1                   1  2621
# 14237             0.000000       1                   0  2633
# 14238             1.318465       1                   1  2656
# 14239             1.146058       1                   1  2695
# 14240             0.000000       1                   1  2711
# 14241             0.093954       1                   1  2726
# 14242             0.651623       1                   0  2732
# 14243             0.000000       1                   1  2754
# 14244             0.000000       1                   1  2797
# 14245             0.551280       1                   1  2823
# 14246             0.329748       1                   1  2833
# 14247             0.000000       1                   0  2840
# 14248             2.545895       1                   1  2849
# 14249             0.548758       1                   1  2860
# 14250             0.000000       1                   0  2936
# 14251             1.351545       1                   1  2942
# 14252             1.480438       1                   1  2948
# 14253             0.343995       1                   1  2968
#
#        _opfilter_pe_veto  shr_tkfit_nhits_Y  ...  CosmicIPAll3D    elec_e  \
# 26905                0.0                  0  ...    9999.000000  0.964566
# 26906                0.0                  4  ...      69.863831  0.128056
# 26907                0.0                  0  ...    9999.000000  1.881477
# 26908                0.0                 11  ...     111.912033  1.795105
# 14233                0.0                  8  ...     127.424110  0.449960
# 14234                0.0                  9  ...      43.686256  0.648535
# 14235                0.0                  0  ...    9999.000000  0.231331
# 14236                0.0                  2  ...     110.500656  0.300216
# 14237                0.0                  0  ...    9999.000000  0.797621
# 14238                0.0                  9  ...      21.510136  1.120504
# 14239                0.0                  6  ...     167.745789  1.473064
# 14240                0.0                  0  ...     128.778656  0.315167
# 14241                0.0                  5  ...     118.327835  0.597527
# 14242                0.0                  5  ...      99.313759  0.686687
# 14243                0.0                  0  ...      50.035507  0.596155
# 14244                0.0                  0  ...      67.850723  1.091015
# 14245                0.0                 13  ...      62.121346  0.805018
# 14246                0.0                  7  ...      29.776413  0.542661
# 14247                0.0                  0  ...    9999.000000  0.453989
# 14248                0.0                 11  ...      65.900215  1.794748
# 14249                0.0                 13  ...      42.809654  0.723578
# 14250                0.0                  0  ...    9999.000000  0.402456
# 14251                0.0                  4  ...     183.906143  2.008060
# 14252                0.0                  8  ...      88.950363  1.217760
# 14253                0.0                  1  ...      75.501358  0.449842
#
#        shr_tkfit_dedx_max  hits_ratio  truthFiducial  shrmoliereavg    trkfit  \
# 26905       -3.402823e+38    0.000000          False  -3.402408e+38  1.000000
# 26906        1.834861e+00    1.000000           True   3.851074e+00  0.110619
# 26907       -3.402823e+38    0.000000          False  -3.402408e+38  1.000000
# 26908        2.030725e+00    1.000000           True   6.402344e+00  0.347054
# 14233        2.964928e+00    0.811594          False   1.757422e+01  0.660714
# 14234        7.098595e+00    0.865239           True   5.437500e+00  0.058224
# 14235       -3.402823e+38    0.000000          False  -3.402408e+38  1.000000
# 14236        3.107745e+00    0.942789          False   6.970703e+00  0.191651
# 14237       -3.402823e+38    0.000000          False  -3.402408e+38  1.000000
# 14238        5.157641e+00    0.834505          False   4.864258e+00  0.235393
# 14239        5.226519e+00    0.843465          False   2.226074e+00  0.079279
# 14240       -3.402823e+38    0.000000           True  -3.402408e+38  1.000000
# 14241        3.977404e+00    0.076336           True   1.853516e+01  0.271429
# 14242        4.962333e+00    0.960169           True   3.157715e+00  0.017652
# 14243       -3.402823e+38    0.000000          False  -3.402408e+38  1.000000
# 14244       -3.402823e+38    0.000000          False  -3.402408e+38  1.000000
# 14245        2.087926e+00    1.000000          False   5.581055e+00  0.211073
# 14246        9.507495e+00    0.660350           True   7.027344e+00  0.346578
# 14247       -3.402823e+38    0.000000          False  -3.402408e+38  1.000000
# 14248        1.999218e+00    0.833656          False   3.366406e+01  0.137222
# 14249        2.193761e+00    1.000000           True   7.212891e+00  0.083258
# 14250       -3.402823e+38    0.000000           True  -3.402408e+38  1.000000
# 14251        2.234015e+00    0.958375           True   4.801758e+00  0.182627
# 14252        2.012400e+00    0.894949           True   3.999512e+00  0.024765
# 14253        3.463659e+00    0.988359           True   5.491211e+00  0.016490
#
#        shr_tkfit_nhits_U  npi0  subcluster
# 26905                  0     0  2147483648
# 26906                  2     0           8
# 26907                  0     0  2147483648
# 26908                  5     0          19
# 14233                  0     0           3
# 14234                  8     0          24
# 14235                  0     0  2147483648
# 14236                 10     1          20
# 14237                  0     0  2147483648
# 14238                  0     0          41
# 14239                  1     0          22
# 14240                  0     0  2147483648
# 14241                  2     0           2
# 14242                  0     0          26
# 14243                  0     0  2147483648
# 14244                  0     0  2147483648
# 14245                 10     0          14
# 14246                  0     0           4
# 14247                  0     1  2147483648
# 14248                  7     1          56
# 14249                  0     0          21
# 14250                  0     0  2147483648
# 14251                  3     0          32
# 14252                  0     1          35
# 14253                  0     0          22
#
# [25 rows x 23 columns]

# %%
t.keys()
# Out:
# ['selected',
#  'run',
#  'sub',
#  'evt',
#  'trk_id',
#  'shr_id',
#  'trk2_id',
#  'shr2_id',
#  'trk3_id',
#  'shr3_id',
#  'shr_energy_tot',
#  'shr_energy',
#  'shr_energy_second',
#  'shr_energy_third',
#  'shr_energy_tot_cali',
#  'shr_energy_cali',
#  'shr_energy_second_cali',
#  'shr_energy_third_cali',
#  'shr_theta',
#  'shr_phi',
#  'shr_pca_0',
#  'shr_pca_1',
#  'shr_pca_2',
#  'shr_px',
#  'shr_py',
#  'shr_pz',
#  'shr_openangle',
#  'shr_tkfit_start_x',
#  'shr_tkfit_start_y',
#  'shr_tkfit_start_z',
#  'shr_tkfit_theta',
#  'shr_tkfit_phi',
#  'shr_start_x',
#  'shr_start_y',
#  'shr_start_z',
#  'shr_dedx_Y',
#  'shr_dedx_V',
#  'shr_dedx_U',
#  'shr_dedx_Y_cali',
#  'shr_dedx_V_cali',
#  'shr_dedx_U_cali',
#  'shr_tkfit_dedx_Y',
#  'shr_tkfit_dedx_V',
#  'shr_tkfit_dedx_U',
#  'shr_tkfit_dedx_max',
#  'shr_tkfit_nhits_Y',
#  'shr_tkfit_nhits_V',
#  'shr_tkfit_nhits_U',
#  'shr_llrpid_dedx_Y',
#  'shr_llrpid_dedx_V',
#  'shr_llrpid_dedx_U',
#  'shr_llrpid_dedx',
#  'shr_tkfit_dedx_Y_alt',
#  'shr_tkfit_dedx_V_alt',
#  'shr_tkfit_dedx_U_alt',
#  'shr_tkfit_nhits_Y_alt',
#  'shr_tkfit_nhits_V_alt',
#  'shr_tkfit_nhits_U_alt',
#  'trkfit',
#  'shr_tkfit_npoints',
#  'shr_tkfit_npointsvalid',
#  'shr_trkfitmedangle',
#  'shrmoliereavg',
#  'shrmoliererms',
#  'shr1shr2moliereavg',
#  'shr1shr2moliererms',
#  'shr1trk1moliereavg',
#  'shr1trk1moliererms',
#  'shr1trk2moliereavg',
#  'shr1trk2moliererms',
#  'ismerged',
#  'merge_bestdot',
#  'merge_bestdist',
#  'merge_vtx_x',
#  'merge_vtx_y',
#  'merge_vtx_z',
#  'merge_tk_ipfp',
#  'shr_tkfit_2cm_dedx_Y',
#  'shr_tkfit_2cm_dedx_V',
#  'shr_tkfit_2cm_dedx_U',
#  'shr_tkfit_2cm_nhits_Y',
#  'shr_tkfit_2cm_nhits_V',
#  'shr_tkfit_2cm_nhits_U',
#  'shr_tkfit_gap05_dedx_Y',
#  'shr_tkfit_gap05_dedx_V',
#  'shr_tkfit_gap05_dedx_U',
#  'shr_tkfit_gap05_nhits_Y',
#  'shr_tkfit_gap05_nhits_V',
#  'shr_tkfit_gap05_nhits_U',
#  'shr_tkfit_gap10_dedx_Y',
#  'shr_tkfit_gap10_dedx_V',
#  'shr_tkfit_gap10_dedx_U',
#  'shr_tkfit_gap10_nhits_Y',
#  'shr_tkfit_gap10_nhits_V',
#  'shr_tkfit_gap10_nhits_U',
#  'shr_chipr',
#  'shr_chimu',
#  'shr_bragg_p',
#  'shr_bragg_mu',
#  'shr_bragg_mip',
#  'shr_bragg_kaon',
#  'shr_bragg_pion',
#  'tksh_distance',
#  'tksh_angle',
#  'shr_distance',
#  'shr_score',
#  'shr_bkt_pdg',
#  'shr_bkt_purity',
#  'shr_bkt_completeness',
#  'shr_bkt_E',
#  'trk_len',
#  'trk_theta',
#  'trk_phi',
#  'trk_energy',
#  'trk_energy_muon',
#  'trk_energy_muon_mcs',
#  'trk_energy_tot',
#  'trk_energy_muon_tot',
#  'trk_distance',
#  'trk_score',
#  'trk_bkt_pdg',
#  'trk_bkt_purity',
#  'trk_bkt_completeness',
#  'trk_bkt_E',
#  'trk_chipr_best',
#  'trk_chipr_worst',
#  'trk_chimu_best',
#  'trk_chimu_worst',
#  'trk_chipr',
#  'trk_chimu',
#  'trk_pida',
#  'trk_bragg_p',
#  'trk_bragg_mu',
#  'trk_bragg_mip',
#  'trk_bragg_kaon',
#  'trk_bragg_pion',
#  'trk_hits_max',
#  'shr_hits_max',
#  'all_shr_hits',
#  'all_trk_hits',
#  'all_shr_energies',
#  'all_trk_energies',
#  'shr_hits_max',
#  'trk_hits_2nd',
#  'shr_hits_2nd',
#  'trk_hits_3rd',
#  'shr_hits_3rd',
#  'trkshrhitdist0',
#  'trkshrhitdist1',
#  'trkshrhitdist2',
#  'trk2shrhitdist0',
#  'trk2shrhitdist1',
#  'trk2shrhitdist2',
#  'trk1trk2hitdist0',
#  'trk1trk2hitdist1',
#  'trk1trk2hitdist2',
#  'total_hits_y',
#  'extra_energy_y',
#  'trk_energy_hits_tot',
#  'subcluster',
#  'shrsubclusters0',
#  'shrsubclusters1',
#  'shrsubclusters2',
#  'shrclusfrac0',
#  'shrclusfrac1',
#  'shrclusfrac2',
#  'shrclusdir0',
#  'shrclusdir1',
#  'shrclusdir2',
#  'shr_hits_tot',
#  'shr_hits_y_tot',
#  'shr_hits_u_tot',
#  'shr_hits_v_tot',
#  'trk_hits_tot',
#  'trk_hits_y_tot',
#  'trk_hits_u_tot',
#  'trk_hits_v_tot',
#  '_elecclusters_U_charge',
#  '_elecclusters_V_charge',
#  '_elecclusters_Y_charge',
#  '_elecclusters_U_N',
#  '_elecclusters_V_N',
#  '_elecclusters_Y_N',
#  'n_tracks_contained',
#  'n_showers_contained',
#  'matched_E',
#  'hits_ratio',
#  'contained_fraction',
#  'sps_contained_fraction',
#  'pt',
#  'p',
#  'pt_assume_muon',
#  'p_assume_muon',
#  'reco_e',
#  'nblips_saved',
#  'blip_x',
#  'blip_y',
#  'blip_z',
#  'blip_dx',
#  'blip_dw',
#  'blip_energy',
#  'blip_charge',
#  'blip_nplanes',
#  'blip_proxtrkdist',
#  'blip_proxtrkid',
#  'blip_touchtrk',
#  'blip_touchtrkid',
#  'blip_pl0_nwires',
#  'blip_pl1_nwires',
#  'blip_pl2_nwires',
#  'blip_pl0_bydeadwire',
#  'blip_pl1_bydeadwire',
#  'blip_pl2_bydeadwire',
#  'blip_true_g4id',
#  'blip_true_pdg',
#  'blip_true_energy',
#  'dvtx',
#  'dtrk',
#  'contained_sps_ratio',
#  'dtrk_x_boundary',
#  'dtrk_y_boundary',
#  'dtrk_z_boundary',
#  'dshr_x_boundary',
#  'dshr_y_boundary',
#  'dshr_z_boundary',
#  'dvtx_x_boundary',
#  'dvtx_y_boundary',
#  'dvtx_z_boundary',
#  'dtrk_boundary',
#  'dvtx_boundary',
#  'dshr_boundary',
#  'dmc_boundary',
#  'CosmicIP',
#  'CosmicIPAll3D',
#  'CosmicDirAll3D',
#  'CosmicIPAll2DEnds',
#  'CosmicDirAll2DEnds',
#  'CosmicIPAll2DOvlp',
#  'CosmicDirAll2DOvlp',
#  'leeweight',
#  'true_pt',
#  'true_pt_visible',
#  'true_p',
#  'true_p_visible',
#  'true_e_visible',
#  '_opfilter_pe_beam',
#  '_opfilter_pe_veto',
#  'nu_pdg',
#  'ccnc',
#  'nu_parent_pdg',
#  'nu_hadron_pdg',
#  'nu_decay_mode',
#  'interaction',
#  'resid',
#  'nu_e',
#  'nu_l',
#  'nu_pt',
#  'theta',
#  'w',
#  'Q2',
#  'x',
#  'y',
#  'isVtxInFiducial',
#  'truthFiducial',
#  'true_nu_vtx_t',
#  'true_nu_vtx_x',
#  'true_nu_vtx_y',
#  'true_nu_vtx_z',
#  'true_nu_vtx_sce_x',
#  'true_nu_vtx_sce_y',
#  'true_nu_vtx_sce_z',
#  'reco_nu_vtx_x',
#  'reco_nu_vtx_y',
#  'reco_nu_vtx_z',
#  'reco_nu_vtx_sce_x',
#  'reco_nu_vtx_sce_y',
#  'reco_nu_vtx_sce_z',
#  'nmuon',
#  'muon_e',
#  'muon_c',
#  'muon_p',
#  'nelec',
#  'elec_e',
#  'elec_c',
#  'elec_p',
#  'elec_vx',
#  'elec_vy',
#  'elec_vz',
#  'elec_px',
#  'elec_py',
#  'elec_pz',
#  'npi0',
#  'pi0_e',
#  'pi0_c',
#  'pi0_p',
#  'nneutron',
#  'nproton',
#  'proton_e',
#  'proton_c',
#  'proton_p',
#  'npion',
#  'pion_e',
#  'pion_c',
#  'pion_p',
#  'neta',
#  'eta_e',
#  'nslice',
#  'crtveto',
#  'crthitpe',
#  'pfp_slice_idx',
#  'category',
#  'backtracked_pdg',
#  'backtracked_e',
#  'backtracked_tid',
#  'backtracked_purity',
#  'backtracked_completeness',
#  'backtracked_overlay_purity',
#  'backtracked_px',
#  'backtracked_py',
#  'backtracked_pz',
#  'backtracked_start_x',
#  'backtracked_start_y',
#  'backtracked_start_z',
#  'backtracked_start_t',
#  'backtracked_start_U',
#  'backtracked_start_V',
#  'backtracked_start_Y',
#  'backtracked_sce_start_x',
#  'backtracked_sce_start_y',
#  'backtracked_sce_start_z',
#  'backtracked_sce_start_U',
#  'backtracked_sce_start_V',
#  'backtracked_sce_start_Y',
#  'lep_e',
#  'pass',
#  'swtrig',
#  'evnhits',
#  'slpdg',
#  'slnhits',
#  'n_pfps',
#  'n_tracks',
#  'n_showers',
#  'pfp_generation_v',
#  'pfp_trk_daughters_v',
#  'pfp_shr_daughters_v',
#  'pfp_n_descendents_v',
#  'pfp_vtx_x_v',
#  'pfp_vtx_y_v',
#  'pfp_vtx_z_v',
#  'trk_score_v',
#  'pfpdg',
#  'pfnhits',
#  'pfnplanehits_U',
#  'pfnplanehits_V',
#  'pfnplanehits_Y',
#  'pfpplanesubclusters_U',
#  'pfpplanesubclusters_V',
#  'pfpplanesubclusters_Y',
#  'pfpplanesubhitfracmax_U',
#  'pfpplanesubhitfracmax_V',
#  'pfpplanesubhitfracmax_Y',
#  'hits_u',
#  'hits_v',
#  'hits_y',
#  'slice_id',
#  'slice_topo_score_v',
#  'topological_score',
#  'slclustfrac',
#  'mc_trackid',
#  'mc_mother',
#  'mc_pdg',
#  'mc_E',
#  'mc_n_elastic',
#  'mc_n_inelastic',
#  'mc_vx',
#  'mc_vy',
#  'mc_vz',
#  'mc_endx',
#  'mc_endy',
#  'mc_endz',
#  'mc_px',
#  'mc_py',
#  'mc_pz',
#  'mc_end_p',
#  'mc_generator_pdg',
#  'mc_generator_mother',
#  'mc_generator_rescatter',
#  'mc_generator_trackid',
#  'mc_generator_statuscode',
#  'mc_generator_E',
#  'mc_generator_px',
#  'mc_generator_py',
#  'mc_generator_pz',
#  'mc_completeness',
#  'mc_purity',
#  'endmuonprocess',
#  'endmuonmichel',
#  'filter_antibdt',
#  'filter_ncpi0',
#  'filter_pi0',
#  'filter_ccinclusive',
#  'weights',
#  'weights/weights.first',
#  'weights/weights.second',
#  'weightsFlux',
#  'weightsGenie',
#  'weightsReint',
#  'weightSpline',
#  'weightTune',
#  'weightSplineTimesTune',
#  'knobRPAup',
#  'knobRPAdn',
#  'knobCCMECup',
#  'knobCCMECdn',
#  'knobAxFFCCQEup',
#  'knobAxFFCCQEdn',
#  'knobVecFFCCQEup',
#  'knobVecFFCCQEdn',
#  'knobDecayAngMECup',
#  'knobDecayAngMECdn',
#  'knobThetaDelta2Npiup',
#  'knobThetaDelta2Npidn',
#  'knobThetaDelta2NRadup',
#  'knobThetaDelta2NRaddn',
#  'knobNormCCCOHup',
#  'knobNormCCCOHdn',
#  'knobNormNCCOHup',
#  'knobNormNCCOHdn',
#  'knobxsr_scc_Fv3up',
#  'knobxsr_scc_Fv3dn',
#  'knobxsr_scc_Fa3up',
#  'knobxsr_scc_Fa3dn',
#  'RootinoFix',
#  'flash_pe_flash_matching',
#  'flash_pe_flash_matching_v',
#  'slice_pe_flash_matching_v',
#  'flash_time_flash_matching',
#  'flash_y_flash_matching',
#  'flash_z_flash_matching',
#  'flash_timewidth_flash_matching',
#  'flash_ywidth_flash_matching',
#  'flash_zwidth_flash_matching',
#  'nu_flashmatch_score',
#  'nu_centerX',
#  'nu_centerY',
#  'nu_centerZ',
#  'nu_totalCharge',
#  'best_cosmic_flashmatch_score',
#  'best_obviouscosmic_flashmatch_score',
#  'cosmic_flashmatch_score_v',
#  'cosmic_topological_score_v',
#  'cosmic_centerX_v',
#  'cosmic_centerY_v',
#  'cosmic_centerZ_v',
#  'cosmic_totalCharge_v',
#  'cosmic_nhits_v',
#  'cosmic_nunhits_v',
#  'cosmic_isclear_v',
#  'slice_orig_pass_id',
#  'slice_orig_topo_score',
#  'mcf_nu_e',
#  'mcf_lep_e',
#  'mcf_actvol',
#  'mcf_nmm',
#  'mcf_nmp',
#  'mcf_nem',
#  'mcf_nep',
#  'mcf_np0',
#  'mcf_npp',
#  'mcf_npm',
#  'mcf_mcshr_elec_etot',
#  'mcf_pass_ccpi0',
#  'mcf_pass_ncpi0',
#  'mcf_pass_ccnopi',
#  'mcf_pass_ncnopi',
#  'mcf_pass_cccpi',
#  'mcf_pass_nccpi',
#  'X_SpcPts_v',
#  'Y_SpcPts_v',
#  'Z_SpcPts_v',
#  'shr_id_MCStool',
#  'shr_hits_max_MCStool',
#  'n_showers_contained_MCStool',
#  'trkshrscore_v',
#  'shrPCA_1Cr',
#  'shrPCA_2Cr',
#  'shrPCA_3Cr',
#  'shrPCA_1Ce',
#  'shrPCA_2Ce',
#  'shrPCA_3Ce',
#  'shrPCA1CAS',
#  'shrPCA2CAS',
#  'shrPCA3CAS',
#  'shrPCA_1Cr2h',
#  'shrPCA_2Cr2h',
#  'shrPCA_3Cr2h',
#  'shrPCA_1Cr1h',
#  'shrPCA_2Cr1h',
#  'shrPCA_3Cr1h',
#  'shrMCSMom',
#  'shrMCSMom1h',
#  'shrMCSMom2h',
#  'shrPCALen',
#  'n_shrSpcPts',
#  'PCAWin_1Cr_5cm',
#  'PCAWin_2Cr_5cm',
#  'PCAWin_3Cr_5cm',
#  'PCAWin_dist_5cm',
#  'PCAWin_npts_5cm',
#  'shrStart_5cm',
#  'shrStartMCS_5cm',
#  'shrMCSAS_5cm',
#  'shrPCA1CAS_5cm',
#  'shrPCA2CAS_5cm',
#  'shrPCA3CAS_5cm',
#  'shrPCA1CMed_5cm',
#  'PCAWin_1Cr_2_5cm',
#  'PCAWin_2Cr_2_5cm',
#  'PCAWin_3Cr_2_5cm',
#  'PCAWin_dist_2_5cm',
#  'PCAWin_npts_2_5cm',
#  'shrStart_2_5cm',
#  'shrStartMCS_2_5cm',
#  'shrMCSAS_2_5cm',
#  'shrPCA1CAS_2_5cm',
#  'shrPCA2CAS_2_5cm',
#  'shrPCA3CAS_2_5cm',
#  'shrPCA1CMed_2_5cm',
#  'DeltaMed',
#  'DeltaMed1h',
#  'DeltaMed2h',
#  'DeltaRMS',
#  'DeltaRMS1h',
#  'DeltaRMS2h',
#  'CylFrac_1cm',
#  'CylFrac1h_1cm',
#  'CylFrac2h_1cm',
#  'CylFrac_2cm',
#  'CylFrac1h_2cm',
#  'CylFrac2h_2cm',
#  'CylFrac_3cm',
#  'CylFrac1h_3cm',
#  'CylFrac2h_3cm',
#  'CylFrac_4cm',
#  'CylFrac1h_4cm',
#  'CylFrac2h_4cm',
#  'CylFrac_5cm',
#  'CylFrac1h_5cm',
#  'CylFrac2h_5cm',
#  'NeutrinoEnergy0',
#  'NeutrinoEnergy1',
#  'NeutrinoEnergy2',
#  'SliceCaloEnergy0',
#  'SliceCaloEnergy1',
#  'SliceCaloEnergy2',
#  'slcng2mip',
#  'slcng2hip',
#  'slcng2shr',
#  'slcng2mcl',
#  'slcng2dfs',
#  'slcng2bkg',
#  'clung2mip',
#  'clung2hip',
#  'clung2shr',
#  'clung2mcl',
#  'clung2dfs',
#  'clung2bkg',
#  'pfng2semlabel',
#  'pfng2mipfrac',
#  'pfng2hipfrac',
#  'pfng2shrfrac',
#  'pfng2mclfrac',
#  'pfng2dfsfrac',
#  'pfng2bkgfrac',
#  'pfng2mipavrg',
#  'pfng2hipavrg',
#  'pfng2shravrg',
#  'pfng2mclavrg',
#  'pfng2dfsavrg',
#  'pfng2bkgavrg',
#  'nhits_r1cm',
#  'nhits_r3cm',
#  'nhits_r5cm',
#  'nhits_r10cm',
#  'ng2hip_r1cm',
#  'ng2hip_r3cm',
#  'ng2hip_r5cm',
#  'ng2hip_r10cm',
#  'ng2clu_hip_r1cm',
#  'ng2clu_hip_r3cm',
#  'ng2clu_hip_r5cm',
#  'ng2clu_hip_r10cm',
#  'ng2clu_hippfp_r1cm',
#  'ng2clu_hippfp_r3cm',
#  'ng2clu_hippfp_r5cm',
#  'ng2clu_hippfp_r10cm',
#  'pfng2hip_r1cm',
#  'pfng2hip_r3cm',
#  'pfng2hip_r5cm',
#  'pfng2hip_r10cm',
#  'pi0_mcgamma0_e',
#  'pi0_mcgamma0_px',
#  'pi0_mcgamma0_py',
#  'pi0_mcgamma0_pz',
#  'pi0_mcrcdot0',
#  'pi0_mcrce0',
#  'pi0_mcgamma1_e',
#  'pi0_mcgamma1_px',
#  'pi0_mcgamma1_py',
#  'pi0_mcgamma1_pz',
#  'pi0_mcrcdot1',
#  'pi0_mcrce1',
#  'pi0_nshower',
#  'pi0_ntrack',
#  'pi0_ngamma',
#  'pi0_radlen1',
#  'pi0_radlen2',
#  'pi0_dot1',
#  'pi0_dot2',
#  'pi0_energy1_Y',
#  'pi0_energy2_Y',
#  'pi0_dir1_x',
#  'pi0_dir1_y',
#  'pi0_dir1_z',
#  'pi0_dir2_x',
#  'pi0_dir2_y',
#  'pi0_dir2_z',
#  'pi0_dedx1_Y',
#  'pi0_dedx2_Y',
#  'pi0_dedx1_fit_Y',
#  'pi0_dedx2_fit_Y',
#  'pi0_energy1_V',
#  'pi0_energy2_V',
#  'pi0_dedx1_V',
#  'pi0_dedx2_V',
#  'pi0_dedx1_fit_V',
#  'pi0_dedx2_fit_V',
#  'pi0_energy1_U',
#  'pi0_energy2_U',
#  'pi0_dedx1_U',
#  'pi0_dedx2_U',
#  'pi0_dedx1_fit_U',
#  'pi0_dedx2_fit_U',
#  'pi0_shrscore1',
#  'pi0_shrscore2',
#  'pi0_gammadot',
#  'pi0_mass_Y',
#  'pi0_mass_V',
#  'pi0_mass_U',
#  'pi0_rc_vtx_x',
#  'pi0_rc_vtx_y',
#  'pi0_rc_vtx_z',
#  'pi0truth_gamma_parent',
#  'pi0truth_elec_edep',
#  'pi0truth_elec_etot',
#  'pi0truth_elec_dist',
#  'pi0truth_elec_parent',
#  'pi0truth_gamma1_tid',
#  'pi0truth_gamma1_edep',
#  'pi0truth_gamma1_etot',
#  'pi0truth_gamma1_dist',
#  'pi0truth_gamma1_elec1',
#  'pi0truth_gamma1_elec2',
#  'pi0truth_gamma1_xpos',
#  'pi0truth_gamma1_ypos',
#  'pi0truth_gamma1_zpos',
#  'pi0truth_gamma2_tid',
#  'pi0truth_gamma2_edep',
#  'pi0truth_gamma2_etot',
#  'pi0truth_gamma2_dist',
#  'pi0truth_gamma2_elec1',
#  'pi0truth_gamma2_elec2',
#  'pi0truth_gamma2_xpos',
#  'pi0truth_gamma2_ypos',
#  'pi0truth_gamma2_zpos',
#  'pi0truth_gammadot',
#  'pi0truth_run',
#  'pi0truth_sub',
#  'pi0truth_evt',
#  'nflag_pl1',
#  'nnoise_pl1',
#  'nslhits_pl1',
#  'nslnoise_pl1',
#  'nhits_pl1',
#  'frac_slnoise_pl1',
#  'secondshower_U_charge',
#  'secondshower_U_nhit',
#  'secondshower_U_vtxdist',
#  'secondshower_U_eigenratio',
#  'secondshower_U_dot',
#  'secondshower_U_dir',
#  'secondshower_V_charge',
#  'secondshower_V_nhit',
#  'secondshower_V_vtxdist',
#  'secondshower_V_eigenratio',
#  'secondshower_V_dot',
#  'secondshower_V_dir',
#  'secondshower_Y_charge',
#  'secondshower_Y_nhit',
#  'secondshower_Y_vtxdist',
#  'secondshower_Y_eigenratio',
#  'secondshower_Y_dot',
#  'secondshower_Y_dir',
#  'secondshower_U_03_ncluster',
#  'secondshower_V_03_ncluster',
#  'secondshower_Y_03_ncluster',
#  'secondshower_U_10_ncluster',
#  'secondshower_V_10_ncluster',
#  'secondshower_Y_10_ncluster',
#  'secondshower_U_20_ncluster',
#  'secondshower_V_20_ncluster',
#  'secondshower_Y_20_ncluster',
#  'shr_dedx_u_v',
#  'shr_dedx_v_v',
#  'shr_dedx_y_v',
#  'shr_energy_u_v',
#  'shr_energy_v_v',
#  'shr_energy_y_v',
#  'shr_pfp_id_v',
#  'shr_start_x_v',
#  'shr_start_y_v',
#  'shr_start_z_v',
#  'shr_dist_v',
#  'shr_start_U_v',
#  'shr_start_V_v',
#  'shr_px_v',
#  'shr_py_v',
#  'shr_pz_v',
#  'shr_openangle_v',
#  'shr_theta_v',
#  'shr_phi_v',
#  'shr_pitch_u_v',
#  'shr_pitch_v_v',
#  'shr_pitch_y_v',
#  'shr_tkfit_nhits_v',
#  'shr_tkfit_start_x_v',
#  'shr_tkfit_start_y_v',
#  'shr_tkfit_start_z_v',
#  'shr_tkfit_start_U_v',
#  'shr_tkfit_start_V_v',
#  'shr_tkfit_theta_v',
#  'shr_tkfit_phi_v',
#  'shr_tkfit_pitch_u_v',
#  'shr_tkfit_pitch_v_v',
#  'shr_tkfit_pitch_y_v',
#  'shr_tkfit_dedx_u_v',
#  'shr_tkfit_dedx_v_v',
#  'shr_tkfit_dedx_y_v',
#  'shr_tkfit_gap10_dedx_u_v',
#  'shr_tkfit_gap10_dedx_v_v',
#  'shr_tkfit_gap10_dedx_y_v',
#  'shr_tkfit_dedx_nhits_u_v',
#  'shr_tkfit_dedx_nhits_v_v',
#  'shr_tkfit_dedx_nhits_y_v',
#  'shr_llr_pid_u_v',
#  'shr_llr_pid_v_v',
#  'shr_llr_pid_y_v',
#  'shr_llr_pid_v',
#  'shr_llr_pid_score_v',
#  'shr_moliere_avg_v',
#  'shr_moliere_rms_v',
#  'origevnhits',
#  'origevnunhits',
#  'origevnunhits2',
#  'origevlepnhits',
#  'origevpronhits',
#  'origevpi1nhits',
#  'origevpi0nhits',
#  'origevneunhits',
#  'origevgamnhits',
#  'origevothnhits',
#  'prefiltnhits',
#  'prefiltnunhits',
#  'prefiltnunhits2',
#  'prefiltlepnhits',
#  'prefiltpronhits',
#  'prefiltpi1nhits',
#  'prefiltpi0nhits',
#  'prefiltneunhits',
#  'prefiltgamnhits',
#  'prefiltothnhits',
#  'evnunhits',
#  'evlepnhits',
#  'evpronhits',
#  'evpi1nhits',
#  'evpi0nhits',
#  'evneunhits',
#  'evgamnhits',
#  'evothnhits',
#  'slnunhits',
#  'sllepnhits',
#  'slpronhits',
#  'slpi1nhits',
#  'slpi0nhits',
#  'slneunhits',
#  'slgamnhits',
#  'slothnhits',
#  'pfnunhits',
#  'pflepnhits',
#  'pfpronhits',
#  'pfpi1nhits',
#  'pfpi0nhits',
#  'pfneunhits',
#  'pfgamnhits',
#  'pfothnhits',
#  'nu_completeness_from_pfp',
#  'nu_purity_from_pfp',
#  'interaction_time_abs',
#  'interaction_time_modulo',
#  'pmt_size',
#  'Med_TT3',
#  'pmt_timeProp',
#  'pmt_time',
#  'mc_interaction_time',
#  'sim_time_offset',
#  'spill_time',
#  'decay_time',
#  'propagation_time',
#  'trk_bragg_p_v',
#  'trk_bragg_mu_v',
#  'trk_bragg_pion_v',
#  'trk_bragg_mip_v',
#  'trk_bragg_p_alt_dir_v',
#  'trk_bragg_mu_alt_dir_v',
#  'trk_bragg_pion_alt_dir_v',
#  'trk_bragg_p_fwd_preferred_v',
#  'trk_bragg_mu_fwd_preferred_v',
#  'trk_bragg_pion_fwd_preferred_v',
#  'trk_pida_v',
#  'trk_pid_chipr_v',
#  'trk_pid_chipi_v',
#  'trk_pid_chika_v',
#  'trk_pid_chimu_v',
#  'trk_bragg_p_u_v',
#  'trk_bragg_mu_u_v',
#  'trk_bragg_pion_u_v',
#  'trk_bragg_mip_u_v',
#  'trk_bragg_p_alt_dir_u_v',
#  'trk_bragg_mu_alt_dir_u_v',
#  'trk_bragg_pion_alt_dir_u_v',
#  'trk_bragg_p_fwd_preferred_u_v',
#  'trk_bragg_mu_fwd_preferred_u_v',
#  'trk_bragg_pion_fwd_preferred_u_v',
#  'trk_pida_u_v',
#  'trk_pid_chipr_u_v',
#  'trk_pid_chipi_u_v',
#  'trk_pid_chika_u_v',
#  'trk_pid_chimu_u_v',
#  'trk_bragg_p_v_v',
#  'trk_bragg_mu_v_v',
#  'trk_bragg_pion_v_v',
#  'trk_bragg_mip_v_v',
#  'trk_bragg_p_alt_dir_v_v',
#  'trk_bragg_mu_alt_dir_v_v',
#  'trk_bragg_pion_alt_dir_v_v',
#  'trk_bragg_p_fwd_preferred_v_v',
#  'trk_bragg_mu_fwd_preferred_v_v',
#  'trk_bragg_pion_fwd_preferred_v_v',
#  'trk_pida_v_v',
#  'trk_pid_chipr_v_v',
#  'trk_pid_chipi_v_v',
#  'trk_pid_chika_v_v',
#  'trk_pid_chimu_v_v',
#  'trk_pfp_id_v',
#  'trk_dir_x_v',
#  'trk_dir_y_v',
#  'trk_dir_z_v',
#  'trk_start_x_v',
#  'trk_start_y_v',
#  'trk_start_z_v',
#  'trk_sce_start_x_v',
#  'trk_sce_start_y_v',
#  'trk_sce_start_z_v',
#  'trk_end_x_v',
#  'trk_end_y_v',
#  'trk_end_z_v',
#  'trk_sce_end_x_v',
#  'trk_sce_end_y_v',
#  'trk_sce_end_z_v',
#  'trk_distance_v',
#  'trk_theta_v',
#  'trk_phi_v',
#  'trk_len_v',
#  'trk_mcs_muon_mom_v',
#  'trk_range_muon_mom_v',
#  'trk_energy_proton_v',
#  'trk_energy_muon_v',
#  'trk_calo_energy_u_v',
#  'trk_calo_energy_v_v',
#  'trk_calo_energy_y_v',
#  'trk_llr_pid_u_v',
#  'trk_llr_pid_v_v',
#  'trk_llr_pid_y_v',
#  'trk_llr_pid_v',
#  'trk_llr_pid_score_v',
#  'trk_trunk_dEdx_u_v',
#  'trk_trunk_dEdx_v_v',
#  'trk_trunk_dEdx_y_v',
#  'trk_trunk_rr_dEdx_u_v',
#  'trk_trunk_rr_dEdx_v_v',
#  'trk_trunk_rr_dEdx_y_v',
#  'trk_nhits_u_v',
#  'trk_nhits_v_v',
#  'trk_nhits_y_v',
#  'trk_avg_deflection_mean_v',
#  'trk_avg_deflection_stdev_v',
#  'trk_avg_deflection_separation_mean_v',
#  'trk_end_spacepoints_v']

# %%
# Set the files to grab nue data

directory = 'DetVar/v01/'

file_names = [
#               'prodgenie_bnb_intrinsic_nue_overlay_detvar_sce_reco2_run1_reco2_reco2.root',
              'prodgenie_bnb_intrinsic_nue_overlay_DetVar_wiremod_ScaledEdX_v08_00_00_42_run1_reco2_reco2.root',
              'prodgenie_bnb_intrinsic_nue_overlay_DetVar_wiremod_ScaleX_v08_00_00_42_run1_reco2_reco2.root',
              'prodgenie_bnb_intrinsic_nue_overlay_DetVar_wiremod_ScaleYZ_v08_00_00_42_run1_reco2_reco2.root',
              'prodgenie_bnb_intrinsic_nue_overlay_DetVar_WireModAngleXZ_v08_00_00_42_run1_reco2_reco2.root',
#               'prodgenie_bnb_intrinsic_nue_overlay_DetVar_WireModAngleYZ_v08_00_00_42_run1_reco2_reco2.root'
#               'dontuse_____prodgenie_bnb_intrinsic_nue_overlay_DetVar_wiremod_ScaleX_v08_00_00_42_run1_reco2_reco2.root'
              'prodgenie_bnb_intrinsic_nue_overlay_DetVar_CV_reco2_v08_00_00_38_run1_reco2_reco2.root'
             ]

variation_titles = [ 
#                     'sce', 
                    'wiremode_ScaledEdX', 
                    'wiremod_ScaleX', 
                    'wiremod_ScaleYZ', 
                    'WireModAngleXZ', 
#                     'WireModAngleYZ'
#                     'wiremod_ScaleX (10%)'
                    'CV'
                   ]

mode = 'Nue'

# %%
# Set the files to grab pi0 data (cuts are different so dont use)

# directory = 'DetVar/v00/'

# file_names = ['prodgenie_nc_pi0_overlay_DetVar_CV_reco2_v08_00_00_38_run3a_reco2_reco2.root',
# #               'prodgenie_nc_pi0_overlay_DetVar_SCE_reco2_v08_00_00_38_run3a_reco2_reco2.root',
#               'prodgenie_nc_pi0_overlay_DetVar_wiremod_ScaledEdX_v08_00_00_39_run3a_reco2_reco2.root',
#               'prodgenie_nc_pi0_overlay_DetVar_wiremod_ScaleX_v08_00_00_38_run3a_reco2_reco2.root',
# #               'prodgenie_nc_pi0_overlay_DetVar_wiremod_ScaleYZ_v08_00_00_38_run3a_reco2_reco2.root',
#               'prodgenie_nc_pi0_overlay_DetVar_WireModAngleXZ_v08_00_00_38_run3a_reco2_reco2.root',
#               'prodgenie_nc_pi0_overlay_DetVar_WireModAngleYZ_v08_00_00_38_run3a_reco2_reco2.root'
#              ]

# variation_titles = ['CV', 
# #                     'sce', 
#                     'wiremode_ScaledEdX', 
#                     'wiremod_ScaleX', 
# #                     'wiremod_ScaleYZ', 
#                     'WireModAngleXZ', 
#                     'WireModAngleYZ'
#                    ]

# mode='Pi0'

# %%
# Util functions

def get_elm_from_vec_idx(myvec, idx, fillval=np.nan):
    """Returns the element of a vector at position idx, where idx is a vector of indices. If idx is out of bounds, returns a filler value"""
    return np.array([pidv[tid] if ((tid < len(pidv)) & (tid >= 0)) else fillval for pidv, tid in zip(myvec, idx)])

def get_idx_from_vec_sort(argidx, vecsort, mask):
    """Returns the index of the element of a vector at position argidx, where argidx is a vector of indices. If argidx is out of bounds, returns -1."""
    vid = vecsort[mask]
    sizecheck = argidx if argidx >= 0 else abs(argidx) - 1
    # find the position in the array after masking
    mskd_pos = [ak.argsort(v)[argidx] if len(v) > sizecheck else -1 for v in vid]
    # go back to the corresponding position in the origin array before masking
    result = [[i for i, n in enumerate(m) if n == 1][p] if (p) >= 0 else -1 for m, p in zip(mask, mskd_pos)]
    return result

# %%
# Get all of the DataFrames into a list

df_list = []

for file in file_names:
    
    file_name = f'{directory}{file}'
    t = uproot.open(file_name)['nuselection']['NeutrinoSelectionFilter']
    df = t.arrays(variables, library="pd")
    
    # Add trksemblbl and trkpid to the DataFrame
    trk_id_o = t.arrays(["trk_id"], library="np")["trk_id"] - 1 #2k sample
    pfng2semlabel = t.arrays(["pfng2semlabel"])["pfng2semlabel"]
    trk_pfng2semlabel_sel = get_elm_from_vec_idx(pfng2semlabel, trk_id_o)
    df["trksemlbl"] = trk_pfng2semlabel_sel

    trk_llr_pid_v = t.arrays(["trk_llr_pid_score_v"])["trk_llr_pid_score_v"]
    trk_id = t.arrays(["trk_id"], library="np")["trk_id"] - 1
    trk_llr_pid_v_sel = get_elm_from_vec_idx(trk_llr_pid_v, trk_id)
    df["trkpid"] = trk_llr_pid_v_sel
    
    # Add unique event identifier to the DataFrame
    df['ident_id'] = df['run'] * 100000 + df['evt']
    
    # Add shr_tkfit_nhits_tot to the DataFrame
    df['shr_tkfit_nhits_tot'] = df['shr_tkfit_nhits_Y'] + df['shr_tkfit_nhits_U'] + df['shr_tkfit_nhits_V']
    
    # Fix unsigned columns so that differences are two-sided
    uint_cols = np.unique(df.select_dtypes(include=['uint32']).columns.to_numpy())
    df[uint_cols] = df[uint_cols].astype('int32')
    
    # Reindex based on the unique event-run value
    df = df.set_index('ident_id')

    df_list.append(df)

# %% [markdown]
# ## Filter out events that are shared between CV and DetVar

# %%
cv_index = df_list[-1].index # Assume CV is the last in the list

share_rate = []
shared_index = []

for i in range(len(df_list)):
    
    # Filter out specific events of interest
    df_before = df_list[i]
    df_before = df_before[df_before['truthFiducial'] == True] 
    df_before = df_before[df_before['npi0'] == 0]
    
    num_total_events = len(df_before.index) # Number of events before intersection
    
    shared_index.append(df_before.index.intersection(cv_index)) # Store the index intersection
    
    num_shared_events = len(shared_index[i]) # Number of events after intersection
    
    share_rate.append(num_shared_events / num_total_events)
    
print(f'Of the {len(cv_index)} CV events, this ratio is shared with DetVar:\n {share_rate}')
# Out:
# Of the 88471 CV events, this ratio is shared with DetVar:
#  [0.9688043478260869, 0.9637149380300065, 0.9645100758750103, 0.9659366740385134, 1.0]

# %% [markdown]
# ## Remove special values from shared_index

# %%
removeSpecial = True

if np.all([len(i)==0 for i in shared_index[:-1]]):
    removeSpecial = False
    print("Setting to False")

if removeSpecial:
    
    og_shared_index = shared_index[:]
    
    for i in range(len(df_list)-1):
        
        cv_share = df_list[-1].loc[shared_index[i]]
        detvar_share = df_list[i].loc[shared_index[i]]
        
        shared_index[i] = shared_index[i].intersection(cv_share[~cv_share[var].isin(special)].index)
        shared_index[i] = shared_index[i].intersection(cv_share[~cv_share[var2].isin(special2)].index)
        shared_index[i] = shared_index[i].intersection(detvar_share[~detvar_share[var].isin(special)].index)
        shared_index[i] = shared_index[i].intersection(detvar_share[~detvar_share[var2].isin(special2)].index)     
        
else:
    
    shared_index = og_shared_index[:]

# %% [markdown]
# ## Make new set of indices that section off first variable points

# %%
# May error on the first time since it relies on var and bins that are initialized later

sectioned_index = []

# section = -0.1 # Percentage distance from 0 that gets sectioned off (negative means on the low side, positive on the high side)
section_label = '<' # Which direction to cut
section_value = -0.02 # Which value to cut on (interpretation depends on uncommented code below)

def performSectioning():

    for i in range(len(df_list)-1):

        detvar = df_list[i].loc[shared_index[i]][var]
        cv = df_list[-1].loc[shared_index[i]][var]

        relative_error = ( detvar - cv ) / cv

        if section_label == '>':
            new_index = df_list[i].loc[shared_index[i]][relative_error > section_value].index
        elif section_label == '<':
            new_index = df_list[i].loc[shared_index[i]][relative_error < section_value].index
        elif section_label == '=':
            new_index = df_list[i].loc[shared_index[i]][relative_error == section_value].index
        else:
            new_index = shared_index[i] # Should cause no change

#         error = detvar - cv

#         if section == '+':
#             new_index = df_list[i].loc[shared_index[i]][error > 0].index
#         elif section == '-':
#             new_index = df_list[i].loc[shared_index[i]][error < 0].index
#         else:
#             new_index = shared_index[i] # Should cause no change
            
#         error = (detvar - cv)/np.max(bins)

#         if section > 0:
#             new_index = df_list[i].loc[shared_index[i]][error > section].index
#         elif section < 0:
#             new_index = df_list[i].loc[shared_index[i]][error < section].index
#         else:
#             new_index = shared_index[i] # Should cause no change

        sectioned_index.append(shared_index[i].intersection(new_index))
        
performSectioning()

# %% [markdown]
# ## Calculate Differences

# %%
# Pick all of the variables for now (can reduce later)

selected_vars = list(np.copy(variables))
selected_vars.extend(added_vars)
selected_vars = list(set(selected_vars))

df_cv = df_list[-1][selected_vars]
df_diff_list = [] # Differences between detvar and CV (doesn't include CV compared with itself)
df_var_shared_list = [] # Values of DetVar with shared index with CV
df_cv_shared_list = [] # Values of CV with shared index with DetVar

for i in range(len(df_list)-1):
    
    df_var = df_list[i][selected_vars]
    
    df_var_filtered = df_var.loc[shared_index[i]]
    
    df_cv_filtered = df_cv.loc[shared_index[i]]
    
    # And a sign to unsigned datatype columns so that the diff is two-sided
    # And turn boolean values into integers to allow for subtraction
    uint_cols = np.unique(df_var_filtered.select_dtypes(include=['uint32', 'bool']).columns.to_numpy())
    df_var_filtered[uint_cols] = df_var_filtered[uint_cols].astype('int32')
    
#     print(df_var_filtered.dtypes)

    df_var_shared_list.append(df_var_filtered)
    df_cv_shared_list.append(df_cv_filtered)
    
    df_var_filtered.sub(df_cv_filtered, axis='columns') # Stores the difference between CV and DetVar
    df_diff_list.append(df_diff)

# %% [markdown]
# ## Set Up Variable to Plot

# %%
var_bounds = {
    'hits_ratio': {
        'bins': np.linspace(0, 1, 20),
        'err_bins': np.linspace(-0.1, 0.1, 24),
        'limits': [0.40],
        'limit_tag' : '>',
        'special' : []
    },
    'shr_energy_tot_cali': {
        'bins': np.linspace(0, 2, 30),
        'err_bins': np.linspace(-0.075, 0.075, 24),
        'limits': [0.07],
        'limit_tag' : '>',
        'special' : []
    },
    'shrmoliereavg': {
        'bins': np.linspace(0, 50, 20),
        'err_bins': np.linspace(-1, 1, 15),
        'limits': [22],
        'limit_tag' : '<',
        'special' : []
    },
    'shr_tkfit_dedx_max': {
        'bins': np.linspace(0, 7, 20),
        'err_bins': np.linspace(-0.1, 0.1, 24),
        'limits': [1, 3],
        'limit_tag' : '>',
        'special' : []
    },
    'n_tracks_contained': {
        'bins': np.linspace(-0.5, 7.5, 9),
        'err_bins': np.linspace(-2.5, 2.5, 6),
        'limits': [1],
        'limit_tag' : '>',
        'special' : []
    },
    'subcluster': {
        'bins': np.linspace(-0.5, 50.5, 52),
        'err_bins': np.linspace(-5.5, 5.5, 12),
        'limits': [4],
        'limit_tag' : '>',
        'special' : []
    },
    'trkfit': {
        'bins': np.linspace(0, 1, 20),
        'err_bins': np.linspace(-2, 2, 20),
        'limits': [0.5],
        'limit_tag' : '<',
        'special' : []
    },
    'CosmicIPAll3D': {
        'bins': np.linspace(0, 10000, 20),
        'err_bins': np.linspace(-10000, 10000, 20),
        'limits': [0.5],
        'limit_tag' : '>',
        'special' : []
    },
    'n_showers_contained': {
        'bins': np.linspace(-0.5, 8.5, 10),
        'err_bins': np.linspace(-6.5, 6.5, 14),
        'limits': [1],
        'limit_tag' : '==',
        'special' : []
    },
    'tksh_distance': { # Has values at integer limit
        'bins': np.linspace(0, 15, 20),
        'err_bins': np.linspace(-10, 10, 20),
        'limits': [4],
        'limit_tag' : '<',
        'special' : []
    },
    'trksemlbl': {
        'bins': np.linspace(-0.5, 4.5, 6),
        'err_bins': np.linspace(-0.5, 4.5, 6),
        'limits': [1],
        'limit_tag' : '=',
        'special' : []
    },
    '_opfilter_pe_beam': {
        'bins': np.linspace(0, 150, 30),
        'err_bins': np.linspace(-25, 25, 20),
        'limits': [0],
        'limit_tag' : '>',
        'special' : []
    },
    '_opfilter_pe_veto': {
        'bins': np.linspace(0, 100, 30),
        'err_bins': np.linspace(-25, 25, 20),
        'limits': [20],
        'limit_tag' : '<',
        'special' : []
    },
    'shr_tkfit_nhits_tot': {
        'bins': np.linspace(-0.5, 30.5, 32),
        'err_bins': np.linspace(-5, 5, 20),
        'limits': [20],
        'limit_tag' : '<',
        'special' : []
    }
}

var = 'shr_energy_tot_cali'
var2 = 'shr_tkfit_dedx_max'
performSectioning()

def getBounds(var):
    
    if var in var_bounds.keys():
        bins = var_bounds[var]['bins']
        err_bins = var_bounds[var]['err_bins']
        limits = var_bounds[var]['limits']
        limit_tag = var_bounds[var]['limit_tag']
        special = var_bounds[var]['special']
    else:
        diff_values = [[df[var].min(), df[var].max()] for df in df_diff_list]
        df_values = [[df[var].min(), df[var].max()] for df in df_list]

    #     print(df_list[-1][var].dtype)

        if df_list[-1][var].dtype in ['uint32','int32']:
            bin_min = np.round(np.min(df_values))-0.5
            bin_max = np.round(np.max(df_values))+0.5
            bins = np.linspace(bin_min, bin_max, int(bin_max - bin_min + 1))

            err_bin_min = np.round(np.min(diff_values))-0.5
            err_bin_max = np.round(np.max(diff_values))+0.5
            err_bins = np.linspace(err_bin_min, err_bin_max, int(err_bin_max - err_bin_min + 1))
        else:
            bins = np.linspace(np.min(df_values), np.max(df_values),20)
            err_bins = np.linspace(np.min(diff_values), np.max(df_values),20)

        limits = []
        limit_tag = ''
        special = []

        print(bins)
        print(err_bins)
    
    bin_centers = (bins[:-1]+bins[1:])/2
    bin_width = bins[1]-bins[0]

    err_bin_centers = (err_bins[:-1]+err_bins[1:])/2
    err_bin_width = err_bins[1]-err_bins[0]
        
    return bins, err_bins, limits, limit_tag, special, bin_centers, bin_width, err_bin_centers, err_bin_width

bins, err_bins, limits, limit_tag, special, bin_centers, bin_width, err_bin_centers, err_bin_width = getBounds(var)

bins2, err_bins2, limits2, limit_tag2, special2, bin_centers2, bin_width2, err_bin_centers2, err_bin_width2 = getBounds(var2)

# %% [markdown]
# ## Create Errorbar Plots (for first variable)

# %%
labels = variation_titles[:-1]
linestyles = ('-',':','.-','--')

rel_errors = [] # Store the relative errors for sectioning

err_fig, err_ax = plt.subplots(dpi=100)
    
for i in range(len(df_list)-1):
    
    detvar = df_list[i].loc[shared_index[i]][var]
    cv = df_list[-1].loc[shared_index[i]][var]
    
    relative_error = ( detvar - cv ) / cv
    
    rel_errors.append(relative_error)
    
    hist = np.histogram(relative_error,err_bins)[0]
    
    err_ax.errorbar(err_bin_centers,hist/sum(hist),xerr=err_bin_width/2,ls='none',marker='s',ms=2.5,lw=1,label=labels[i])
    
err_ax.axvline(section_value, ls='--',c='k', linewidth=0.8)
    
err_ax.grid(True)
err_ax.legend(framealpha=1)
err_ax.set_xlim(min(err_bins), max(err_bins))
err_ax.set_title(f'Distribution of errors in {var} between CV and variations')
err_ax.set_ylabel('Relative Frequency (Counts/Total)')
err_ax.set_xlabel(f'Relative Error in {var} [(DetVar - CV)/CV]');

# %% [markdown]
# ## Create 2D Histograms (for first variable)

# %%
hist2d_fig, hist2d_axs = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True, dpi=150)

axs = hist2d_axs.flatten()

# Get the maximum bin value to set as the vmax
vmax = 10
for i in range(len(df_list)-1):
    vmax = max(vmax, np.max(np.histogram2d(df_list[-1].loc[shared_index[i]][var], df_list[i].loc[shared_index[i]][var], bins=bins)[0]))
      
for i in range(len(df_list)-1):
    
    _,_,_,im = axs[i].hist2d(df_list[-1].loc[shared_index[i]][var], df_list[i].loc[shared_index[i]][var], 
                             bins=bins, norm=mpl.colors.LogNorm(vmax=vmax))
    
    
    axs[i].set_title(f'{variation_titles[i]}')
    
    for limit in limits: 
        axs[i].axvline(limit, ls='--',c='k', linewidth=0.8)
        axs[i].axhline(limit, ls='--',c='k', linewidth=0.8)
    
#     axs[i].set_ylabel(f'{var} (DetVar)')

    # Add diagonal line
    axs[i].plot([0,max(bins)], [0,max(bins)], linestyle='-', c='k', linewidth=0.9, alpha=0.8)

hist2d_fig.supylabel(f'{var} (DetVar)')
hist2d_fig.supxlabel(f'{var} (CV)')
hist2d_fig.suptitle(f'Differences in {var} between CV and DetVar')

hist2d_fig.colorbar(im, ax=axs.ravel().tolist());
    
# plt.tight_layout()

# %% [markdown]
# ## Create 2D Histograms (for first variable) based on first variable section

# %%
hist2d_fig, hist2d_axs = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True, dpi=150)

axs = hist2d_axs.flatten()

# Get the maximum bin value to set as the vmax
vmax = 10
for i in range(len(df_list)-1):
    vmax = max(vmax, np.max(np.histogram2d(df_list[-1].loc[sectioned_index[i]][var], df_list[i].loc[sectioned_index[i]][var], bins=bins)[0]))
    print(vmax)
    
for i in range(len(df_list)-1):
    
    _,_,_,im = axs[i].hist2d(df_list[-1].loc[sectioned_index[i]][var], df_list[i].loc[sectioned_index[i]][var], bins=bins, norm=mpl.colors.LogNorm(vmax=vmax))
    axs[i].set_title(f'{variation_titles[i]}')
    
    for limit in limits: 
        axs[i].axvline(limit, ls='--',c='k', linewidth=0.8)
        axs[i].axhline(limit, ls='--',c='k', linewidth=0.8)
    
#     axs[i].set_ylabel(f'{var} (DetVar)')

    # Add diagonal lines
    axs[i].plot([0,max(bins)], [0,max(bins)], linestyle=':', c='k', linewidth=0.7, alpha=0.8)
    if section_label in ['>', '<']:
        axs[i].plot([0,max(bins)], [0,max(bins)*(1+section_value)], linestyle='-', c='k', linewidth=0.9, alpha=0.8)
    
#     hist2d_fig.colorbar(im, ax=axs[i])

hist2d_fig.supylabel(f'{var} (DetVar)')
hist2d_fig.supxlabel(f'{var} (CV)')
hist2d_fig.suptitle(f'Differences in {var} between CV and DetVar: ({section_label}{section_value*100}%) diagonal')

hist2d_fig.colorbar(im, ax=axs.ravel().tolist());
    
# plt.tight_layout();
# Out:
# 247.0
# 1202.0
# 1202.0
# 1202.0

# %% [markdown]
# ## Create 2D Histograms (for second variable)

# %%
hist2d_fig, hist2d_axs = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True, dpi=150)

axs = hist2d_axs.flatten()

# Get the maximum bin value to set as the vmax
vmax = 10
for i in range(len(df_list)-1):
    vmax = max(vmax, np.max(np.histogram2d(df_list[-1].loc[shared_index[i]][var2], df_list[i].loc[shared_index[i]][var2], bins=bins)[0]))
      

for i in range(len(df_list)-1):
    
    _,_,_,im = axs[i].hist2d(df_list[-1].loc[shared_index[i]][var2], df_list[i].loc[shared_index[i]][var2], bins=bins2, norm=mpl.colors.LogNorm(vmax=vmax))
    axs[i].set_title(f'{variation_titles[i]}')
    
    for limit in limits2: 
        axs[i].axvline(limit, ls='--',c='k', linewidth=0.8)
        axs[i].axhline(limit, ls='--',c='k', linewidth=0.8)
    
#     axs[i].set_ylabel(f'{var} (DetVar)')

    # Add diagonal line
    axs[i].plot([0,max(bins2)], [0,max(bins2)], linestyle='-', c='k', linewidth=0.9, alpha=0.8)

hist2d_fig.supylabel(f'{var2} (DetVar)')
hist2d_fig.supxlabel(f'{var2} (CV)')
hist2d_fig.suptitle(f'Differences in {var2} between CV and DetVar')

hist2d_fig.colorbar(im, ax=axs.ravel().tolist());
    
# plt.tight_layout()

# %% [markdown]
# ## Create 2D Histograms (for second variable) based on first variable section

# %%
hist2d_fig, hist2d_axs = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True, dpi=150)

axs = hist2d_axs.flatten()

# Get the maximum bin value to set as the vmax
vmax = 10
for i in range(len(df_list)-1):
    vmax = max(vmax, np.max(np.histogram2d(df_list[-1].loc[sectioned_index[i]][var2], df_list[i].loc[sectioned_index[i]][var2], bins=bins)[0]))

for i in range(len(df_list)-1):
    
    _,_,_,im = axs[i].hist2d(df_list[-1].loc[sectioned_index[i]][var2], df_list[i].loc[sectioned_index[i]][var2], bins=bins2, norm=mpl.colors.LogNorm(vmax=vmax))
    axs[i].set_title(f'{variation_titles[i]}')
    
    for limit in limits2: 
        axs[i].axvline(limit, ls='--',c='k', linewidth=0.8)
        axs[i].axhline(limit, ls='--',c='k', linewidth=0.8)
    
#     axs[i].set_ylabel(f'{var} (DetVar)')

    # Add diagonal line
    axs[i].plot([0,max(bins2)], [0,max(bins2)], linestyle='-', c='k', linewidth=0.9, alpha=0.8)

hist2d_fig.supylabel(f'{var2} (DetVar)')
hist2d_fig.supxlabel(f'{var2} (CV)')
hist2d_fig.suptitle(f'Differences in {var2} between CV and DetVar events: ({section_label}{section_value*100}%) diagonal in {var}')

hist2d_fig.colorbar(im, ax=axs.ravel().tolist());
    
# plt.tight_layout()

# %% [markdown]
# ## More unnecessary plots

# %%
# Create scatter plot
scatter_fig, scatter_axs = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True, dpi=150, )

axs = scatter_axs.flatten()

for i in range(len(df_shared_list)):
    
    axs[i].scatter(df_cv_shared_list[i][var], df_shared_list[i][var], s=2, alpha=0.2, marker='.')
    axs[i].set_title(f'{variation_titles[i]}')
    
#     axs[i].set_xlabel(f'{var} (CV)')
#     axs[i].set_ylabel(f'{var} (DetVar)')
    
    axs[i].set_xlim(min(bins), max(bins))
    axs[i].set_ylim(min(bins), max(bins))
    
    for limit in limits: 
        axs[i].axvline(limit, ls='--',c='k', linewidth=0.8)
        axs[i].axhline(limit, ls='--',c='k', linewidth=0.8)
    
#     axs[i].set_aspect('equal')
    
scatter_fig.supylabel(f'{var} (DetVar)')
scatter_fig.supxlabel(f'{var} (CV)')
scatter_fig.suptitle(f'Differences in {var} between CV and DetVar')
    
plt.tight_layout()

# %%
hist2d_fig, hist2d_axs = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True, dpi=150)

axs = hist2d_axs.flatten()

for i in range(len(df_list)-1):
    
    _,_,_,im = axs[i].hist2d(df_list[-1].loc[shared_index[i]][var], df_list[i].loc[shared_index[i]][var], bins=bins)
    axs[i].set_title(f'{variation_titles[i]}')
    
    for limit in limits: 
        axs[i].axvline(limit, ls='--',c='k', linewidth=0.8)
        axs[i].axhline(limit, ls='--',c='k', linewidth=0.8)
    
#     axs[i].set_ylabel(f'{var} (DetVar)')

hist2d_fig.supylabel(f'{var} (DetVar)')
hist2d_fig.supxlabel(f'{var} (CV)')
hist2d_fig.suptitle(f'Differences in {var} between CV and DetVar')

hist2d_fig.colorbar(im, ax=axs.ravel().tolist());
    
# plt.tight_layout()

# %%
# Plot as lines
# linestyles = ('-',':','.-','--','')

values = []
counts = []
totals = []
lines_fig, lines_ax = plt.subplots(dpi=100)

for i in range(len(df_list)):
    values.append(np.array(df_list[i][var]))
    counts.append(np.histogram(values[i],bins)[0])
    totals.append(sum(counts[i]))

    lines_ax.errorbar(bin_centers,counts[i]/totals[i],xerr=bin_width/2,ls='none',marker='s',ms=2.5,lw=1, label=variation_titles[i]) #, edgecolor='black')

for limit in limits: 
    lines_ax.axvline(limit, ls=':',c='k', label=f'{var} limit')
    
lines_ax.legend(framealpha=1)
lines_ax.set_title(f'Distribution of {var} in CV and variations')
lines_ax.set_ylabel('Relative Frequency')
lines_ax.set_xlabel(f'{var}');

# %% [markdown]
# ## Miscut Survey

# %%
# Function to determine whether a point is within/outside of the limits in both values -> bool

def isMiscut(value1, value2, limits, tag='<'):
    if len(limits) == 1 and tag != '=':
        return not ((value1 < limits[0]) ^ (value2 < limits[0]))
            
    elif len(limits) ==1 and tag == '=':
        return not ((value1 == limits[0]) ^ (value2 == limits[0]))
        
    elif len(limits) == 2: # Assumes the cut is between the two
        return not (((value1 < limits[0]) ^ (value1 < limits[1])) ^ ((value2 < limits[0]) ^ (value2 < limits[1])))
        
    elif len(limits) == 0:
        return True
    
    else:
        raise ValueError("limits must have only 0, 1 or 2 values")

# %%
df_event_run_errors = pd.DataFrame(index=df_list[-1].index) # DataFrame to store miscut rates
df_event_run_errors['Total'] = 0

for key in var_bounds.keys():
    bins = var_bounds[key]['bins']
    err_bins = var_bounds[key]['err_bins']
    limits = var_bounds[key]['limits']
    limit_tag = var_bounds[key]['limit_tag']
    
    df_event_run_errors[key] = 0
    
    for i in range(len(df_list)-1):
        
        df_event_run_errors[variation_titles[i]] = 0
        
        for ident_id in shared_index[i]:
            
            cv = df_list[-1].loc[ident_id][key]
            detvar = df_list[i].loc[ident_id][key]
            
            if isMiscut(cv, detvar, limits, tag = limit_tag):
                df_event_run_errors.at[ident_id,key] += 1
            df_event_run_errors.at[ident_id,'Total'] += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_70562/4246957938.py in <module>
#      32     hist, bins = np.histogram(counts, 20)
#      33
# ---> 34     ax.hist(bins, hist)
#
# NameError: name 'ax' is not defined

# %%
fig_miscut, axs_miscut = plt.subplots(nrows=1, ncols=len(df_list)-1)   
axs = axs_miscut.flatten()
            
for i in range(len(axs)):    
    
    counts = df_event_run_errors[variation_titles[i]].to_numpy()
    totals = df_event_run_errors['Total'].to_numpy()
    
    hist, bins = np.histogram(counts, 20)
    
    axs[i].hist(hist, bins)

# %% [markdown]
# # Repeat for all of the Detector Variations

# %%
# Perform the cuts (and filter out events that are in both CV and the current DetVar)

is_shared = False
cv_events = np.array(df_list[0]["ident_id"]) # Assume CV is the first in the list
num_shared_events = []

cut_efficiency_list = []
num_total_events = []
bin_counts_before = []

for i in range(len(df_list)):
    
    # Before cuts filter out specific events
    df_before = df_list[i]
    df_before = df_before[df_before['truthFiducial'] == True] 
    df_before = df_before[df_before['npi0'] == 0]
    
    # Get number of events and remove ones that aren't shared with CV if desired
    num_total_events.append(len(np.unique(np.array(df_before['ident_id']))))
    
    if is_shared: df_before = df_before[df_before['ident_id'].isin(cv_events)]
    
    num_shared_events.append(len(np.unique(np.array(df_before['ident_id']))))
    
    # Preselection
    df_pre = df_before
    df_pre = df_pre[df_pre['nslice'] == 1] 
    df_pre = df_pre[df_pre['selected'] == 1]
    df_pre = df_pre[df_pre['shr_energy_tot_cali'] > 0.07]
    df_pre = df_pre[(df_pre['_opfilter_pe_beam'] > 0) & (df_pre['_opfilter_pe_veto'] < 20)]
#     df_pre = df_pre[df_pre['slice_orig_pass_id'] == 1] # original slice id cut
    
    # Cuts
    df_cut = df_pre
    df_cut = df_cut[df_cut['n_tracks_contained'] > 0] # cut to separate Np and 0p
    df_cut = df_cut[df_cut['CosmicIPAll3D'] > 10]
    df_cut = df_cut = df_cut[df_cut['trksemlbl'] == 1]
    df_cut = df_cut = df_cut[df_cut['hits_ratio'] > 0.40]
    df_cut = df_cut = df_cut[df_cut['shrmoliereavg'] < 22]
    df_cut = df_cut = df_cut[df_cut['subcluster'] > 4]
    df_cut = df_cut = df_cut[df_cut['trkfit'] < 0.5]
    df_cut = df_cut = df_cut[df_cut['tksh_distance'] < 4.0]
    df_cut = df_cut[df_cut['shr_tkfit_nhits_tot'] > 1]
    df_cut = df_cut = df_cut[df_cut['shr_tkfit_dedx_max'] > 1]
    df_cut = df_cut = df_cut[df_cut['shr_tkfit_dedx_max'] < 3]
    df_cut = df_cut = df_cut[df_cut['n_showers_contained'] == 1]
    
    # Split into histograms based on energy bins defined above
    energies_before = np.array(df_before['elec_e'])
    energies_cut = np.array(df_cut['elec_e'])

    counts_before, _ = np.histogram(energies_before, bins)
    counts_cut, _ = np.histogram(energies_cut, bins)
    
    # Add information for efficiency and error to arrays for accessing later
    cut_efficiency_list.append(counts_cut/counts_before)
    bin_counts_before.append(counts_before)
